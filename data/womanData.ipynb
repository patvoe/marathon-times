# %%
import pandas as pd

## make one csv from multiple csv in a folder
import os
import glob

path = r'./data/woman/' # use your path
all_files = glob.glob(os.path.join(path, "*.csv"))

df_from_each_file = (pd.read_csv(f) for f in all_files)

concatenated_df   = pd.concat(df_from_each_file, ignore_index=True)
concatenated_df.to_csv( "combined_woman_2004-2024.csv", index=False)

# %%
# import pycountry for country code
import pycountry

# %%
## read the combined csv
pd.set_option('display.max_rows', None)
df_woman = pd.read_csv('combined_woman_2004-2024.csv')
df_woman.head()
# Out:
#    Rank     Mark  WIND        Competitor          DOB  Nat Pos  Unnamed: 7  \
# 0     1  2:14:04   NaN     Brigid KOSGEI  20 FEB 1994  KEN   1         NaN
# 1     2  2:17:08   NaN  Ruth CHEPNGETICH  08 AUG 1994  KEN   1         NaN
# 2     3  2:17:41   NaN   Worknesh DEGEFA  28 OCT 1990  ETH   2         NaN
# 3     4  2:18:30   NaN       Roza DEREJE  09 MAY 1997  ETH   1         NaN
# 4     5  2:18:33   NaN     Azmera ABREHA  31 JAN 1998  ETH   2         NaN
#
#                Venue         Date  Results Score
# 0  Chicago, IL (USA)  13 OCT 2019           1295
# 1        Dubai (UAE)  25 JAN 2019           1263
# 2        Dubai (UAE)  25 JAN 2019           1257
# 3     Valencia (ESP)  01 DEC 2019           1249
# 4     Valencia (ESP)  01 DEC 2019           1248

# %%
# add a column for year use the year of Date column
df_woman['Year'] = pd.DatetimeIndex(df_woman['Date']).year

df_woman.head(20)
# Out:
#     Rank     Mark  WIND                  Competitor          DOB  Nat Pos  \
# 0      1  2:14:04   NaN               Brigid KOSGEI  20 FEB 1994  KEN   1
# 1      2  2:17:08   NaN            Ruth CHEPNGETICH  08 AUG 1994  KEN   1
# 2      3  2:17:41   NaN             Worknesh DEGEFA  28 OCT 1990  ETH   2
# 3      4  2:18:30   NaN                 Roza DEREJE  09 MAY 1997  ETH   1
# 4      5  2:18:33   NaN               Azmera ABREHA  31 JAN 1998  ETH   2
# 5      6  2:18:46   NaN              Birhane DIBABA  11 SEP 1993  ETH   3
# 6      7  2:18:52   NaN   Vivian Jepkemei CHERUIYOT  11 SEP 1983  KEN   4
# 7      8  2:19:10   NaN               Valary JEMELI  08 JUN 1991  KEN   1
# 8      9  2:19:26   NaN             Degitu AZIMERAW  24 JAN 1999  ETH   1
# 9     10  2:19:28   NaN               Zeineba YIMER  17 JUN 1998  ETH   5
# 10    11  2:19:46   NaN      Lonah Chemtai SALPETER  12 DEC 1988  ISR   1
# 11    12  2:19:52   NaN                Tigist GIRMA  12 JUL 1993  ETH   2
# 12    13  2:20:14   NaN               Ashete BEKERE  17 APR 1988  ETH   1
# 13    14  2:20:21   NaN                 Mare DIBABA  20 OCT 1989  ETH   2
# 14    15  2:20:24   NaN             Workenesh EDESA  11 SEP 1992  ETH   6
# 15    16  2:20:39   NaN  Purity Cherotich RIONORIPO  10 JUN 1993  KEN   7
# 16    17  2:20:40   NaN                    Ruti AGA  16 JAN 1994  ETH   1
# 17    18  2:20:48   NaN                Azmera GEBRU  31 OCT 1995  ETH   3
# 18    19  2:20:51   NaN             Ababel YESHANEH  22 JUL 1991  ETH   2
# 19    20  2:20:52   NaN              Gladys CHERONO  12 MAY 1983  KEN   4
#
#     Unnamed: 7              Venue         Date  Results Score  Year
# 0          NaN  Chicago, IL (USA)  13 OCT 2019           1295  2019
# 1          NaN        Dubai (UAE)  25 JAN 2019           1263  2019
# 2          NaN        Dubai (UAE)  25 JAN 2019           1257  2019
# 3          NaN     Valencia (ESP)  01 DEC 2019           1249  2019
# 4          NaN     Valencia (ESP)  01 DEC 2019           1248  2019
# 5          NaN     Valencia (ESP)  01 DEC 2019           1246  2019
# 6          NaN     Valencia (ESP)  01 DEC 2019           1245  2019
# 7          NaN    Frankfurt (GER)  27 OCT 2019           1242  2019
# 8          NaN    Amsterdam (NED)  20 OCT 2019           1239  2019
# 9          NaN     Valencia (ESP)  01 DEC 2019           1239  2019
# 10         NaN        Praha (CZE)  05 MAY 2019           1236  2019
# 11         NaN    Amsterdam (NED)  20 OCT 2019           1235  2019
# 12         NaN       Berlin (GER)  29 SEP 2019           1231  2019
# 13         NaN       Berlin (GER)  29 SEP 2019           1230  2019
# 14         NaN     Valencia (ESP)  01 DEC 2019           1229  2019
# 15         NaN     Valencia (ESP)  01 DEC 2019           1227  2019
# 16         NaN        Tokyo (JPN)  03 MAR 2019           1226  2019
# 17         NaN    Amsterdam (NED)  20 OCT 2019           1225  2019
# 18         NaN  Chicago, IL (USA)  13 OCT 2019           1225  2019
# 19         NaN       London (GBR)  28 APR 2019           1224  2019

# %%
# Convert 'Mark' to timedelta
df_woman['Time'] = pd.to_timedelta(df_woman['Mark'])

# Convert timedelta to total seconds
df_woman['Time_in_seconds'] = df_woman['Time'].dt.total_seconds().astype(int)
df_woman.head(20)
# Out:
#     Rank     Mark  WIND                  Competitor          DOB  Nat Pos  \
# 0      1  2:14:04   NaN               Brigid KOSGEI  20 FEB 1994  KEN   1
# 1      2  2:17:08   NaN            Ruth CHEPNGETICH  08 AUG 1994  KEN   1
# 2      3  2:17:41   NaN             Worknesh DEGEFA  28 OCT 1990  ETH   2
# 3      4  2:18:30   NaN                 Roza DEREJE  09 MAY 1997  ETH   1
# 4      5  2:18:33   NaN               Azmera ABREHA  31 JAN 1998  ETH   2
# 5      6  2:18:46   NaN              Birhane DIBABA  11 SEP 1993  ETH   3
# 6      7  2:18:52   NaN   Vivian Jepkemei CHERUIYOT  11 SEP 1983  KEN   4
# 7      8  2:19:10   NaN               Valary JEMELI  08 JUN 1991  KEN   1
# 8      9  2:19:26   NaN             Degitu AZIMERAW  24 JAN 1999  ETH   1
# 9     10  2:19:28   NaN               Zeineba YIMER  17 JUN 1998  ETH   5
# 10    11  2:19:46   NaN      Lonah Chemtai SALPETER  12 DEC 1988  ISR   1
# 11    12  2:19:52   NaN                Tigist GIRMA  12 JUL 1993  ETH   2
# 12    13  2:20:14   NaN               Ashete BEKERE  17 APR 1988  ETH   1
# 13    14  2:20:21   NaN                 Mare DIBABA  20 OCT 1989  ETH   2
# 14    15  2:20:24   NaN             Workenesh EDESA  11 SEP 1992  ETH   6
# 15    16  2:20:39   NaN  Purity Cherotich RIONORIPO  10 JUN 1993  KEN   7
# 16    17  2:20:40   NaN                    Ruti AGA  16 JAN 1994  ETH   1
# 17    18  2:20:48   NaN                Azmera GEBRU  31 OCT 1995  ETH   3
# 18    19  2:20:51   NaN             Ababel YESHANEH  22 JUL 1991  ETH   2
# 19    20  2:20:52   NaN              Gladys CHERONO  12 MAY 1983  KEN   4
#
#     Unnamed: 7              Venue         Date  Results Score  Year  \
# 0          NaN  Chicago, IL (USA)  13 OCT 2019           1295  2019
# 1          NaN        Dubai (UAE)  25 JAN 2019           1263  2019
# 2          NaN        Dubai (UAE)  25 JAN 2019           1257  2019
# 3          NaN     Valencia (ESP)  01 DEC 2019           1249  2019
# 4          NaN     Valencia (ESP)  01 DEC 2019           1248  2019
# 5          NaN     Valencia (ESP)  01 DEC 2019           1246  2019
# 6          NaN     Valencia (ESP)  01 DEC 2019           1245  2019
# 7          NaN    Frankfurt (GER)  27 OCT 2019           1242  2019
# 8          NaN    Amsterdam (NED)  20 OCT 2019           1239  2019
# 9          NaN     Valencia (ESP)  01 DEC 2019           1239  2019
# 10         NaN        Praha (CZE)  05 MAY 2019           1236  2019
# 11         NaN    Amsterdam (NED)  20 OCT 2019           1235  2019
# 12         NaN       Berlin (GER)  29 SEP 2019           1231  2019
# 13         NaN       Berlin (GER)  29 SEP 2019           1230  2019
# 14         NaN     Valencia (ESP)  01 DEC 2019           1229  2019
# 15         NaN     Valencia (ESP)  01 DEC 2019           1227  2019
# 16         NaN        Tokyo (JPN)  03 MAR 2019           1226  2019
# 17         NaN    Amsterdam (NED)  20 OCT 2019           1225  2019
# 18         NaN  Chicago, IL (USA)  13 OCT 2019           1225  2019
# 19         NaN       London (GBR)  28 APR 2019           1224  2019
#
#               Time  Time_in_seconds
# 0  0 days 02:14:04             8044
# 1  0 days 02:17:08             8228
# 2  0 days 02:17:41             8261
# 3  0 days 02:18:30             8310
# 4  0 days 02:18:33             8313
# 5  0 days 02:18:46             8326
# 6  0 days 02:18:52             8332
# 7  0 days 02:19:10             8350
# 8  0 days 02:19:26             8366
# 9  0 days 02:19:28             8368
# 10 0 days 02:19:46             8386
# 11 0 days 02:19:52             8392
# 12 0 days 02:20:14             8414
# 13 0 days 02:20:21             8421
# 14 0 days 02:20:24             8424
# 15 0 days 02:20:39             8439
# 16 0 days 02:20:40             8440
# 17 0 days 02:20:48             8448
# 18 0 days 02:20:51             8451
# 19 0 days 02:20:52             8452

# %%
# column Nat has iso code and country name, i want add a column with the equivalent two-letter ISO country codes

def get_two_letter_code(nat):
    # Extract the ISO code from the 'Nat' column
    iso_code = nat.split(',')[0].strip()
    try:
        # Get the country object
        country = pycountry.countries.get(alpha_3=iso_code)
        if country:
            return country.alpha_2
    except LookupError:
        return None

def get_correct_alpha3_code(code):
    corrections = {
        'POR': 'PRT',  # Correct ISO alpha-3 for Portugal
        'NED': 'NLD',  # Correct ISO alpha-3 for Netherlands
        'GER': 'DEU',  # Correct ISO alpha-3 for Germany
        'SLO': 'SVK',  # Correct ISO alpha-3 for Slovakia
        'LAT': 'LVA',  # Correct ISO alpha-3 for Latvia
        'TAN': 'TZA',  # Correct ISO alpha-3 for Tanzania
        'RSA': 'ZAF',  # Correct ISO alpha-3 for South Africa
        'MGL': 'MNG',  # Correct ISO alpha-3 for Mongolia
        'SUI': 'CHE'   # Correct ISO alpha-3 for Switzerland
    }
    return corrections.get(code, code)

# Apply the function to create the new column
# Apply the function to correct codes and then get the two-letter ISO codes
df_woman['Nat_Corrected'] = df_woman['Nat'].apply(get_correct_alpha3_code)
df_woman['Two_Letter_ISO'] = df_woman['Nat_Corrected'].apply(get_two_letter_code).str.lower()

df_woman.head(20)
# Out:
#     Rank     Mark  WIND                  Competitor          DOB  Nat Pos  \
# 0      1  2:14:04   NaN               Brigid KOSGEI  20 FEB 1994  KEN   1
# 1      2  2:17:08   NaN            Ruth CHEPNGETICH  08 AUG 1994  KEN   1
# 2      3  2:17:41   NaN             Worknesh DEGEFA  28 OCT 1990  ETH   2
# 3      4  2:18:30   NaN                 Roza DEREJE  09 MAY 1997  ETH   1
# 4      5  2:18:33   NaN               Azmera ABREHA  31 JAN 1998  ETH   2
# 5      6  2:18:46   NaN              Birhane DIBABA  11 SEP 1993  ETH   3
# 6      7  2:18:52   NaN   Vivian Jepkemei CHERUIYOT  11 SEP 1983  KEN   4
# 7      8  2:19:10   NaN               Valary JEMELI  08 JUN 1991  KEN   1
# 8      9  2:19:26   NaN             Degitu AZIMERAW  24 JAN 1999  ETH   1
# 9     10  2:19:28   NaN               Zeineba YIMER  17 JUN 1998  ETH   5
# 10    11  2:19:46   NaN      Lonah Chemtai SALPETER  12 DEC 1988  ISR   1
# 11    12  2:19:52   NaN                Tigist GIRMA  12 JUL 1993  ETH   2
# 12    13  2:20:14   NaN               Ashete BEKERE  17 APR 1988  ETH   1
# 13    14  2:20:21   NaN                 Mare DIBABA  20 OCT 1989  ETH   2
# 14    15  2:20:24   NaN             Workenesh EDESA  11 SEP 1992  ETH   6
# 15    16  2:20:39   NaN  Purity Cherotich RIONORIPO  10 JUN 1993  KEN   7
# 16    17  2:20:40   NaN                    Ruti AGA  16 JAN 1994  ETH   1
# 17    18  2:20:48   NaN                Azmera GEBRU  31 OCT 1995  ETH   3
# 18    19  2:20:51   NaN             Ababel YESHANEH  22 JUL 1991  ETH   2
# 19    20  2:20:52   NaN              Gladys CHERONO  12 MAY 1983  KEN   4
#
#     Unnamed: 7              Venue         Date  Results Score  Year  \
# 0          NaN  Chicago, IL (USA)  13 OCT 2019           1295  2019
# 1          NaN        Dubai (UAE)  25 JAN 2019           1263  2019
# 2          NaN        Dubai (UAE)  25 JAN 2019           1257  2019
# 3          NaN     Valencia (ESP)  01 DEC 2019           1249  2019
# 4          NaN     Valencia (ESP)  01 DEC 2019           1248  2019
# 5          NaN     Valencia (ESP)  01 DEC 2019           1246  2019
# 6          NaN     Valencia (ESP)  01 DEC 2019           1245  2019
# 7          NaN    Frankfurt (GER)  27 OCT 2019           1242  2019
# 8          NaN    Amsterdam (NED)  20 OCT 2019           1239  2019
# 9          NaN     Valencia (ESP)  01 DEC 2019           1239  2019
# 10         NaN        Praha (CZE)  05 MAY 2019           1236  2019
# 11         NaN    Amsterdam (NED)  20 OCT 2019           1235  2019
# 12         NaN       Berlin (GER)  29 SEP 2019           1231  2019
# 13         NaN       Berlin (GER)  29 SEP 2019           1230  2019
# 14         NaN     Valencia (ESP)  01 DEC 2019           1229  2019
# 15         NaN     Valencia (ESP)  01 DEC 2019           1227  2019
# 16         NaN        Tokyo (JPN)  03 MAR 2019           1226  2019
# 17         NaN    Amsterdam (NED)  20 OCT 2019           1225  2019
# 18         NaN  Chicago, IL (USA)  13 OCT 2019           1225  2019
# 19         NaN       London (GBR)  28 APR 2019           1224  2019
#
#               Time  Time_in_seconds Nat_Corrected Two_Letter_ISO
# 0  0 days 02:14:04             8044           KEN             ke
# 1  0 days 02:17:08             8228           KEN             ke
# 2  0 days 02:17:41             8261           ETH             et
# 3  0 days 02:18:30             8310           ETH             et
# 4  0 days 02:18:33             8313           ETH             et
# 5  0 days 02:18:46             8326           ETH             et
# 6  0 days 02:18:52             8332           KEN             ke
# 7  0 days 02:19:10             8350           KEN             ke
# 8  0 days 02:19:26             8366           ETH             et
# 9  0 days 02:19:28             8368           ETH             et
# 10 0 days 02:19:46             8386           ISR             il
# 11 0 days 02:19:52             8392           ETH             et
# 12 0 days 02:20:14             8414           ETH             et
# 13 0 days 02:20:21             8421           ETH             et
# 14 0 days 02:20:24             8424           ETH             et
# 15 0 days 02:20:39             8439           KEN             ke
# 16 0 days 02:20:40             8440           ETH             et
# 17 0 days 02:20:48             8448           ETH             et
# 18 0 days 02:20:51             8451           ETH             et
# 19 0 days 02:20:52             8452           KEN             ke

# %%
# add column Flag_Datawrapper take Two_Letter_ISO in lowercase add : before and after
df_woman['Flag_Datawrapper'] = ':' + df_woman['Two_Letter_ISO'].str.lower() + ':'

df_woman.head(10)
# Out:
#    Rank     Mark  WIND                 Competitor          DOB  Nat Pos  \
# 0     1  2:14:04   NaN              Brigid KOSGEI  20 FEB 1994  KEN   1
# 1     2  2:17:08   NaN           Ruth CHEPNGETICH  08 AUG 1994  KEN   1
# 2     3  2:17:41   NaN            Worknesh DEGEFA  28 OCT 1990  ETH   2
# 3     4  2:18:30   NaN                Roza DEREJE  09 MAY 1997  ETH   1
# 4     5  2:18:33   NaN              Azmera ABREHA  31 JAN 1998  ETH   2
# 5     6  2:18:46   NaN             Birhane DIBABA  11 SEP 1993  ETH   3
# 6     7  2:18:52   NaN  Vivian Jepkemei CHERUIYOT  11 SEP 1983  KEN   4
# 7     8  2:19:10   NaN              Valary JEMELI  08 JUN 1991  KEN   1
# 8     9  2:19:26   NaN            Degitu AZIMERAW  24 JAN 1999  ETH   1
# 9    10  2:19:28   NaN              Zeineba YIMER  17 JUN 1998  ETH   5
#
#    Unnamed: 7              Venue         Date  Results Score  Year  \
# 0         NaN  Chicago, IL (USA)  13 OCT 2019           1295  2019
# 1         NaN        Dubai (UAE)  25 JAN 2019           1263  2019
# 2         NaN        Dubai (UAE)  25 JAN 2019           1257  2019
# 3         NaN     Valencia (ESP)  01 DEC 2019           1249  2019
# 4         NaN     Valencia (ESP)  01 DEC 2019           1248  2019
# 5         NaN     Valencia (ESP)  01 DEC 2019           1246  2019
# 6         NaN     Valencia (ESP)  01 DEC 2019           1245  2019
# 7         NaN    Frankfurt (GER)  27 OCT 2019           1242  2019
# 8         NaN    Amsterdam (NED)  20 OCT 2019           1239  2019
# 9         NaN     Valencia (ESP)  01 DEC 2019           1239  2019
#
#              Time  Time_in_seconds Nat_Corrected Two_Letter_ISO  \
# 0 0 days 02:14:04             8044           KEN             ke
# 1 0 days 02:17:08             8228           KEN             ke
# 2 0 days 02:17:41             8261           ETH             et
# 3 0 days 02:18:30             8310           ETH             et
# 4 0 days 02:18:33             8313           ETH             et
# 5 0 days 02:18:46             8326           ETH             et
# 6 0 days 02:18:52             8332           KEN             ke
# 7 0 days 02:19:10             8350           KEN             ke
# 8 0 days 02:19:26             8366           ETH             et
# 9 0 days 02:19:28             8368           ETH             et
#
#   Flag_Datawrapper
# 0             :ke:
# 1             :ke:
# 2             :et:
# 3             :et:
# 4             :et:
# 5             :et:
# 6             :ke:
# 7             :ke:
# 8             :et:
# 9             :et:

# %%
def get_country_name(iso_code):
    try:
        # Get the country object
        country = pycountry.countries.get(alpha_3=iso_code)
        if country:
            return country.name
    except LookupError:
        return None
    return None

# Apply the function to create the new column
df_woman['Country_Name'] = df_woman['Nat'].apply(get_country_name)

df_woman.head(10)
# Out:
#    Rank     Mark  WIND                 Competitor          DOB  Nat Pos  \
# 0     1  2:14:04   NaN              Brigid KOSGEI  20 FEB 1994  KEN   1
# 1     2  2:17:08   NaN           Ruth CHEPNGETICH  08 AUG 1994  KEN   1
# 2     3  2:17:41   NaN            Worknesh DEGEFA  28 OCT 1990  ETH   2
# 3     4  2:18:30   NaN                Roza DEREJE  09 MAY 1997  ETH   1
# 4     5  2:18:33   NaN              Azmera ABREHA  31 JAN 1998  ETH   2
# 5     6  2:18:46   NaN             Birhane DIBABA  11 SEP 1993  ETH   3
# 6     7  2:18:52   NaN  Vivian Jepkemei CHERUIYOT  11 SEP 1983  KEN   4
# 7     8  2:19:10   NaN              Valary JEMELI  08 JUN 1991  KEN   1
# 8     9  2:19:26   NaN            Degitu AZIMERAW  24 JAN 1999  ETH   1
# 9    10  2:19:28   NaN              Zeineba YIMER  17 JUN 1998  ETH   5
#
#    Unnamed: 7              Venue         Date  Results Score  Year  \
# 0         NaN  Chicago, IL (USA)  13 OCT 2019           1295  2019
# 1         NaN        Dubai (UAE)  25 JAN 2019           1263  2019
# 2         NaN        Dubai (UAE)  25 JAN 2019           1257  2019
# 3         NaN     Valencia (ESP)  01 DEC 2019           1249  2019
# 4         NaN     Valencia (ESP)  01 DEC 2019           1248  2019
# 5         NaN     Valencia (ESP)  01 DEC 2019           1246  2019
# 6         NaN     Valencia (ESP)  01 DEC 2019           1245  2019
# 7         NaN    Frankfurt (GER)  27 OCT 2019           1242  2019
# 8         NaN    Amsterdam (NED)  20 OCT 2019           1239  2019
# 9         NaN     Valencia (ESP)  01 DEC 2019           1239  2019
#
#              Time  Time_in_seconds Nat_Corrected Two_Letter_ISO  \
# 0 0 days 02:14:04             8044           KEN             ke
# 1 0 days 02:17:08             8228           KEN             ke
# 2 0 days 02:17:41             8261           ETH             et
# 3 0 days 02:18:30             8310           ETH             et
# 4 0 days 02:18:33             8313           ETH             et
# 5 0 days 02:18:46             8326           ETH             et
# 6 0 days 02:18:52             8332           KEN             ke
# 7 0 days 02:19:10             8350           KEN             ke
# 8 0 days 02:19:26             8366           ETH             et
# 9 0 days 02:19:28             8368           ETH             et
#
#   Flag_Datawrapper Country_Name
# 0             :ke:        Kenya
# 1             :ke:        Kenya
# 2             :et:     Ethiopia
# 3             :et:     Ethiopia
# 4             :et:     Ethiopia
# 5             :et:     Ethiopia
# 6             :ke:        Kenya
# 7             :ke:        Kenya
# 8             :et:     Ethiopia
# 9             :et:     Ethiopia

# %%
# add a column Gender with "F" for every row
df_woman["Gender"] = "F"
df_woman.head(3)
# Out:
#    Rank     Mark  WIND        Competitor          DOB  Nat Pos  Unnamed: 7  \
# 0     1  2:14:04   NaN     Brigid KOSGEI  20 FEB 1994  KEN   1         NaN
# 1     2  2:17:08   NaN  Ruth CHEPNGETICH  08 AUG 1994  KEN   1         NaN
# 2     3  2:17:41   NaN   Worknesh DEGEFA  28 OCT 1990  ETH   2         NaN
#
#                Venue         Date  Results Score  Year            Time  \
# 0  Chicago, IL (USA)  13 OCT 2019           1295  2019 0 days 02:14:04
# 1        Dubai (UAE)  25 JAN 2019           1263  2019 0 days 02:17:08
# 2        Dubai (UAE)  25 JAN 2019           1257  2019 0 days 02:17:41
#
#    Time_in_seconds Nat_Corrected Two_Letter_ISO Flag_Datawrapper Country_Name  \
# 0             8044           KEN             ke             :ke:        Kenya
# 1             8228           KEN             ke             :ke:        Kenya
# 2             8261           ETH             et             :et:     Ethiopia
#
#   Gender
# 0      F
# 1      F
# 2      F

# %%
# Save the final DataFrame to CSV
df_woman.to_csv('df_woman.csv', index=False)

# %%
# countries of the top 100 fastest woman (Mark=Time)
top_100 = df_woman.sort_values(by='Time_in_seconds', ascending=True).head(100)
top_100['Country_Name'].value_counts().plot(kind='bar', figsize=(10, 6), color='skyblue')
# Out:
# <Axes: xlabel='Country_Name'>

# %%
# Countries by year
countries_by_year = df_woman.groupby(['Year', 'Country_Name']).size().unstack()
# countries_by_year.plot(kind='bar', stacked=True, figsize=(20, 10))

# Top 10 countries by year
top_10_countries_by_year = countries_by_year.sum().nlargest(10).index
top_10_countries_by_year_df = countries_by_year[top_10_countries_by_year]
top_10_countries_by_year_df.plot(kind='bar', stacked=True, figsize=(20, 10))
# Out:
# <Axes: xlabel='Year'>
